# %%
import pandas as pd
import numpy as np

# %%
#считывание данных
StudentsPerformance=pd.read_csv('StudentsPerformance.csv')

# %%
#output first 5 rows
StudentsPerformance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
StudentsPerformance.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#statistics for numeric values
StudentsPerformance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#types of values
StudentsPerformance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#number of rows and columns
StudentsPerformance.shape
# Out:
# (1000, 8)

# %%
#size of dataframe
StudentsPerformance.size
# Out:
# 8000

# %%
#extract columns and rows
StudentsPerformance.iloc[0:5,0:5]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none
# 3                    none
# 4                    none

# %%
#extract needful rows and columns (-1 - the last one from right to left)
StudentsPerformance.iloc[[0,3,10],[0,5,-1]]
# Out:
#     gender  math score  writing score
# 0   female          72             74
# 3     male          47             44
# 10    male          58             52

# %%
#only rows with all columns
StudentsPerformance_with_names=StudentsPerformance.iloc[[0,3,4,7,8]]

# %%
#set names for rows indexes 
StudentsPerformance_with_names.index=["Lupa",'Pupa','Oleg','Ivan','Mark']

# %%
StudentsPerformance_with_names
# Out:
#        gender race/ethnicity parental level of education         lunch  \
# Lupa   female        group B           bachelor's degree      standard
# Pupa     male        group A          associate's degree  free/reduced
# Oleg     male        group C                some college      standard
# Ivan     male        group B                some college  free/reduced
# Masha    male        group D                 high school  free/reduced
#
#       test preparation course  math score  reading score  writing score
# Lupa                     none          72             72             74
# Pupa                     none          47             57             44
# Oleg                     none          76             78             75
# Ivan                     none          40             43             39
# Masha               completed          64             64             67

# %%
#extract rows and columns by its names
StudentsPerformance_with_names.loc[["Lupa",'Pupa'],['gender','math score']]
# Out:
#       gender  math score
# Lupa  female          72
# Pupa    male          47

# %%
#series
StudentsPerformance_with_names.iloc[:,0]
# Out:
# Lupa    female
# Pupa      male
# Oleg      male
# Ivan      male
# Mark      male
# Name: gender, dtype: object

# %%
pd.Series([1,2,3],index=["Lupa",'Pupa','Oleg'])
# Out:
# Lupa    1
# Pupa    2
# Oleg    3
# dtype: int64

# %%
mySeries1=pd.Series([1,2,3],index=["Lupa",'Pupa','Oleg'])
mySeries2=pd.Series([4,5,6],index=["Lupa",'Pupa','Oleg'])

# %%
#create dataframe from series
pd.DataFrame({'col1':mySeries1,'col2':mySeries2})
# Out:
#       col1  col2
# Lupa     1     4
# Pupa     2     5
# Oleg     3     6

# %%
#every columns contain series
StudentsPerformance_with_names['gender']
# Out:
# Lupa    female
# Pupa      male
# Oleg      male
# Ivan      male
# Mark      male
# Name: gender, dtype: object

# %%
StudentsPerformance_with_names[['gender']]
# Out:
#       gender
# Lupa  female
# Pupa    male
# Oleg    male
# Ivan    male
# Mark    male

# %%
StudentsPerformance.gender=='female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
# 5       True
# 6       True
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12      True
# 13     False
# 14      True
# 15      True
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29      True
#        ...
# 970     True
# 971    False
# 972     True
# 973     True
# 974     True
# 975     True
# 976    False
# 977    False
# 978    False
# 979     True
# 980     True
# 981    False
# 982    False
# 983     True
# 984     True
# 985    False
# 986     True
# 987    False
# 988     True
# 989     True
# 990    False
# 991     True
# 992     True
# 993     True
# 994    False
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
#select only that rows, which contain 'female' values
StudentsPerformance.loc[StudentsPerformance.gender=='female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 9    female        group B                 high school  free/reduced
# 12   female        group B                 high school      standard
# 14   female        group A             master's degree      standard
# 15   female        group C            some high school      standard
# 17   female        group B            some high school  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# ...

# %%
#find mean of series
mean_wr_scores=StudentsPerformance['writing score'].mean()

# %%
StudentsPerformance.loc[StudentsPerformance['writing score']>mean_wr_scores]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 13     male        group A                some college      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# ...

# %%
#how to combine two conditions to select rows
query=(StudentsPerformance['writing score']>mean_wr_scores) & (StudentsPerformance.gender=='female')

# %%
StudentsPerformance.loc[query]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 15   female        group C            some high school      standard
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 30   female        group D                some college      standard
# 36   female        group D          associate's degree      standard
# ...

# %%
#see names of columns
StudentsPerformance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#rename columns
StudentsPerformance=StudentsPerformance \
    .rename(columns={'reading score':'reading_score','writing score':'writing_score',
                     'parental level of education':'parental_level_of_education',
                    'math score':'math_score','test preparation course':'test_preparation_course'})

# %%
#more comfortable
StudentsPerformance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
StudentsPerformance.query('writing_score>74')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# 36   female        group D          associate's degree      standard
# ...

# %%
StudentsPerformance.query("gender=='female' & writing_score>74")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 15   female        group C            some high school      standard
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 36   female        group D          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# 47   female        group C                 high school      standard
# 48   female        group D          associate's degree  free/reduced
# 54   female        group C            some high school  free/reduced
# 56   female        group E          associate's degree      standard
# ...

# %%
 writing_score_query=78

# %%
#put @ for using valnurables
StudentsPerformance.query("writing_score>@ writing_score_query")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# 36   female        group D          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# 49     male        group C                 high school      standard
# 54   female        group C            some high school  free/reduced
# 56   female        group E          associate's degree      standard
# 77     male        group A           bachelor's degree      standard
# ...

# %%
#list of col nemes with key word
score=[i for i in list(StudentsPerformance) if 'score' in i]

# %%
StudentsPerformance[score].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
#the same operation using filter
StudentsPerformance.filter(like = 'score').head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
#use filter for rows
StudentsPerformance_with_names.filter(like='e',axis=0)
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# Oleg   male        group C                some college  standard
#
#      test preparation course  math score  reading score  writing score
# Oleg                    none          76             78             75

# %%
#group and apply function
StudentsPerformance.groupby('gender').mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
#specify what funct to use
StudentsPerformance.groupby('gender').aggregate({'math_score':'mean'})
# Out:
#         math_score
# gender
# female   63.633205
# male     68.728216

# %%
StudentsPerformance.groupby('gender',as_index=False).aggregate({'math_score':'mean'}).rename(columns={'math_score':'mean_math_score'})
# Out:
#    gender  mean_math_score
# 0  female        63.633205
# 1    male        68.728216

# %%
StudentsPerformance.groupby(['gender','race/ethnicity'],as_index=False).aggregate({'math_score':'mean'}) \
.rename(columns={'math_score':'mean_math_score'})
# Out:
#    gender race/ethnicity  mean_math_score
# 0  female        group A        58.527778
# 1  female        group B        61.403846
# 2  female        group C        62.033333
# 3  female        group D        65.248062
# 4  female        group E        70.811594
# 5    male        group A        63.735849
# 6    male        group B        65.930233
# 7    male        group C        67.611511
# 8    male        group D        69.413534
# 9    male        group E        76.746479

# %%
StudentsPerformance.math_score.unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8], dtype=int64)

# %%
#top students
StudentsPerformance.sort_values(['gender','math_score'],ascending=False).groupby('gender').head()
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
StudentsPerformance['total_score'] = StudentsPerformance.math_score+StudentsPerformance.reading_score+StudentsPerformance.writing_score

# %%
StudentsPerformance.assign(total_log=np.log(StudentsPerformance.total_score)).head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score  total_score  total_log
# 0          218          218   5.384495
# 1          247          247   5.509388
# ...

# %%
#delete column
StudentsPerformance.drop(['total score'],axis=1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# **Приктические задания по курсу**
#
# неделя 1

# %%
d={'type':['A','A','B','B'],'value':[10,14,12,23]}
df = pd.DataFrame(data=d)

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
subset_1=my_stat.iloc[0:10,[0,2]]
subset_2=my_stat.iloc[:,[1,3]]
subset_2=subset_2.drop([1,5])

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
subset_1=my_stat.query('V1>0 & V3=="A"')
subset_2=my_stat.query('V2!=10 | V4>=1')

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
my_stat['V5']=my_stat['V1']+my_stat['V4']
my_stat=my_stat.assign(V6=np.log(my_stat.V2))

# %%
my_stat=my_stat.rename(columns={'V1' : 'session_value','V2' : 'group','V3' : 'time','V4' : 'n_users'})

# %%
my_stat=pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')

# %%
my_stat.session_value.fillna(0,inplace=True)
a=my_stat[my_stat.n_users >= 0].n_users.median()
my_stat.n_users.where(my_stat.n_users >= 0, a,inplace=True)

# %%
A=my_stat.groupby('group',as_index=False).agg({'session_value': 'mean'})

# %%
mean_session_value_data=A.rename(columns={'session_value': 'mean_session_value'})

# %%
mean_session_value_data
# Out:
#   group  mean_session_value
# 0     A                 0.8
# 1     B                 0.8
